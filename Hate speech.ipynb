# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv("labeled_data.csv")
dataset
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# count                 0
# hate_speech           0
# offensive_language    0
# neither               0
# class                 0
# tweet                 0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 1.3+ MB

# %%
dataset.describe()
# Out:
#          Unnamed: 0         count   hate_speech  offensive_language  \
# count  24783.000000  24783.000000  24783.000000        24783.000000
# mean   12681.192027      3.243473      0.280515            2.413711
# std     7299.553863      0.883060      0.631851            1.399459
# min        0.000000      3.000000      0.000000            0.000000
# 25%     6372.500000      3.000000      0.000000            2.000000
# 50%    12703.000000      3.000000      0.000000            3.000000
# 75%    18995.500000      3.000000      0.000000            3.000000
# max    25296.000000      9.000000      7.000000            9.000000
#
#             neither         class
# count  24783.000000  24783.000000
# mean       0.549247      1.110277
# std        1.113299      0.462089
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        0.000000      1.000000
# 75%        0.000000      1.000000
# max        9.000000      2.000000

# %%
dataset["labels"] = dataset["class"].map({0 : "Hate speech",
                                         1 : "Offensive",
                                         2 : "No hate or offensive language"})
dataset
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet  \
# ...

# %%
dataset["labels"].value_counts()
# Out:
# labels
# Offensive                        19190
# No hate or offensive language     4163
# Hate speech                       1430
# Name: count, dtype: int64

# %%
data = dataset[["tweet", "labels"]]
data
# Out:
#                                                    tweet  \
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                               labels
# 0      No hate or offensive language
# 1                          Offensive
# 2                          Offensive
# 3                          Offensive
# 4                          Offensive
# ...                              ...
# ...

# %%
import re
import nltk
import string

# %%
#Importing stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
# print(stop_words)
# Out:
# {'but', 'before', 'all', 'by', 'other', 'can', 'hers', 'm', 'once', "don't", 'having', "shan't", 'such', "hadn't", "you've", 'if', 'at', 'both', 'as', 'here', "i'd", 'her', "won't", "shouldn't", 'your', 'should', "they're", 'them', "doesn't", 'over', "it's", "needn't", 'me', 'been', "she'll", 'it', 'which', "isn't", 'yourselves', 'an', "you'd", 'y', 'doing', 'ma', 'through', "couldn't", 'under', "should've", 'for', "he'll", 'this', 'where', 'i', 'out', 'to', 'yours', 'won', 'same', 'am', 'very', 'on', "they'd", 'we', 'until', 'from', 'how', 'its', 'mustn', 'down', 's', 'yourself', 'didn', 'has', "i'm", "she's", "you'll", 'don', 'were', 'wouldn', "she'd", "we're", 'a', 'hasn', 'aren', 'd', 'my', 'haven', 'while', 'why', 'then', 'doesn', 'between', "it'll", "weren't", 'do', 'when', 'few', 'itself', 'their', 'hadn', 'he', "aren't", 'mightn', 'herself', 're', 'shouldn', 'most', 'these', 'you', 'had', 'weren', 'couldn', "that'll", "he'd", "didn't", 'each', 'that', "we'd", 'his', 'some', '
# ...

# %%
# Import Stemming
stemmer = nltk.SnowballStemmer("english")

# %%
#Data cleaning
def clean_data(text):
    text = str(text.lower())
    text = re.sub(r'https?://\S|www\.S+', '', text)
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' %re.escape(string.punctuation), '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    #Stop words removal
    text = [word for word in text.split(' ') if word not in stop_words]
    text = " ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text = " ".join(text)
    return text

# def clean_data(text):
#     text = str(text.lower())
#     text = re.sub('https?://\S+|www\.\S+', '', text)
#     text = re.sub('\[.*?\]', '', text)
#     text = re.sub('<.*?>+', '', text)
#     text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
#     text = re.sub('\w*\d\w*', '', text)

#     # Remove stopwords
#     text = [word for word in text.split() if word not in stop_words]

#     # Stemming
#     text = [stemmer.stem(word) for word in text]

#     # Convert back to string
#     return " ".join(text)

# %%
data['tweet'] = data['tweet'].apply(clean_data)
# Out:
# C:\Users\patra\AppData\Local\Temp\ipykernel_15688\3370867953.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['tweet'] = data['tweet'].apply(clean_data)

# %%
data
# Out:
#                                                    tweet  \
# 0       rt mayasolov woman shouldnt complain clean ho...
# 1       rt  boy dat coldtyga dwn bad cuffin dat hoe  ...
# 2       rt urkindofbrand dawg rt  ever fuck bitch sta...
# 3                 rt cganderson vivabas look like tranni
# 4       rt shenikarobert shit hear might true might f...
# ...                                                  ...
# 24778  yous muthafin lie   coreyemanuel right tl tras...
# 24779  youv gone broke wrong heart babi drove redneck...
# 24780  young buck wanna eat dat nigguh like aint fuck...
# 24781                     youu got wild bitch tellin lie
# 24782  ruffl  ntac eileen dahlia  beauti color combin...
#
#                               labels
# 0      No hate or offensive language
# 1                          Offensive
# 2                          Offensive
# 3                          Offensive
# 4                          Offensive
# ...                              ...
# ...

# %%
X = np.array(data['tweet'])
y = np.array(data['labels'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
cv = CountVectorizer()
X = cv.fit_transform(X) #Take each word from sentence and return numbers according to their appearance

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
#Building out ML Model
from sklearn.tree import DecisionTreeClassifier

# %%
dt  = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
print(y_pred)
# Out:
# ['Offensive' 'Offensive' 'Offensive' ... 'Offensive' 'Offensive'
#  'Offensive']

# %%
#Confusion matrix and accuracy
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 164,   33,  268],
#        [  77, 1081,  221],
#        [ 241,  224, 5870]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.heatmap(cm, annot = True, fmt = ".1f", cmap = "YlGnBu")
plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8699107470350899

# %%
sample = "Lets unite and kill all the people who are protesting against goverment"
clean_data(sample)
# Out:
# 'let unit kill peopl protest gover'

# %%
data1 = cv.transform([sample]).toarray()

# %%
data1 #Output is all 0's because after cleaning there is no word that is in the training data of ours
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
dt.predict(data1)
# Out:
# array(['Hate speech'], dtype=object)
